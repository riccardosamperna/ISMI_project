# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2
import numpy as np

img = cv2.imread("./input/train/Type_1/928.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# msk = np.zeros((img.shape[0], img.shape[1]))

crop_img = img[1145:1145+1063 , 326:326+972]

# cv2.rectangle(img,
#               (882, 961),
#               (1924, 2067),
#               255,
#               2)

crop_img = cv2.resize(crop_img, (256, 256))

plt.imshow(crop_img)
plt.show()

# %% [markdown]
# This was put together in a couple of hours using code that I used to participate in other Kaggle events. This is a basic startup for those that are interested in using residual networks using Keras. With the code below, the hardware that I was using is:
#
# 1.    Ubuntu 14.04
# 2.    x64 I7 processor
# 3.    Python 2.7
# 4.    Used PIP installer for all python packages (and apt-get for specialized code such as OpenCV)
# 5.    SSD Harddrive with 1TB storage (I don't think you need more than 100GB though)
# 6.    NVidia 1080 GTX Founders Edition graphics card
#
# This was meant as a starting point to build upon for those that are interested.
#
# Enjoy!
#
# Rodney Thomas

# %%
from __future__ import division

import six
import numpy as np
import pandas as pd
import cv2
import glob
import random

np.random.seed(2016)
random.seed(2016)

# %% [markdown]
# ## Removes autoscroll throughout process

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %% [markdown]
# ## Global Declarations

# %%
conf = dict()

# How many patients will be in train and validation set during training. Range: (0; 1)
conf['train_valid_fraction'] = 0.75

# Batch size for CNN [Depends on GPU and memory available]
conf['batch_size'] = 32

# Number of epochs for CNN training
conf['nb_epoch'] = 100
#conf['nb_epoch'] = 1

# Early stopping. Stop training after epochs without improving on validation
conf['patience'] = 3

# Shape of image for CNN (Larger the better, but you need to increase CNN as well)
#conf['image_shape'] = (4160,4128)
#conf['image_shape'] = (2080,2064)
#conf['image_shape'] = (1024,1024)
conf['image_shape'] = (64,64)

# %% [markdown]
# ## Residual Network Class

# %%
def _bn_relu(input):
    """Helper to build a BN -> relu block
    """
    norm = BatchNormalization(axis=CHANNEL_AXIS)(input)
    return Activation("relu")(norm)

# %%
def _conv_bn_relu(**conv_params):
    """Helper to build a conv -> BN -> relu block
    """
    nb_filter = conv_params["nb_filter"]
    nb_row = conv_params["nb_row"]
    nb_col = conv_params["nb_col"]
    subsample = conv_params.setdefault("subsample", (1, 1))
    init = conv_params.setdefault("init", "he_normal")
    border_mode = conv_params.setdefault("border_mode", "same")
    W_regularizer = conv_params.setdefault("W_regularizer", l2(1.e-4))

    def f(input):
        conv = Convolution2D(nb_filter=nb_filter, nb_row=nb_row, nb_col=nb_col, subsample=subsample,
                             init=init, border_mode=border_mode, W_regularizer=W_regularizer)(input)
        return _bn_relu(conv)

    return f

# %%
def _bn_relu_conv(**conv_params):
    """Helper to build a BN -> relu -> conv block.
    This is an improved scheme proposed in http://arxiv.org/pdf/1603.05027v2.pdf
    """
    nb_filter = conv_params["nb_filter"]
    nb_row = conv_params["nb_row"]
    nb_col = conv_params["nb_col"]
    subsample = conv_params.setdefault("subsample", (1,1))
    init = conv_params.setdefault("init", "he_normal")
    border_mode = conv_params.setdefault("border_mode", "same")
    W_regularizer = conv_params.setdefault("W_regularizer", l2(1.e-4))

    def f(input):
        activation = _bn_relu(input)
        return Convolution2D(nb_filter=nb_filter, nb_row=nb_row, nb_col=nb_col, subsample=subsample,
                             init=init, border_mode=border_mode, W_regularizer=W_regularizer)(activation)

    return f

# %%
def _shortcut(input, residual):
    """Adds a shortcut between input and residual block and merges them with "sum"
    """
    # Expand channels of shortcut to match residual.
    # Stride appropriately to match residual (width, height)
    # Should be int if network architecture is correctly configured.
    input_shape = K.int_shape(input)
    residual_shape = K.int_shape(residual)
    stride_width = int(round(input_shape[ROW_AXIS] / residual_shape[ROW_AXIS]))
    stride_height = int(round(input_shape[COL_AXIS] / residual_shape[COL_AXIS]))
    equal_channels = input_shape[CHANNEL_AXIS] == residual_shape[CHANNEL_AXIS]

    shortcut = input
    # 1 X 1 conv if shape is different. Else identity.
    if stride_width > 1 or stride_height > 1 or not equal_channels:
        shortcut = Convolution2D(nb_filter=residual_shape[CHANNEL_AXIS],
                                 nb_row=1, nb_col=1,
                                 subsample=(stride_width, stride_height),
                                 init="he_normal", border_mode="valid",
                                 W_regularizer=l2(0.0001))(input)

    return merge([shortcut, residual], mode="sum")

# %%
def _residual_block(block_function, nb_filter, repetitions, is_first_layer=False):
    """Builds a residual block with repeating bottleneck blocks.
    """
    def f(input):
        for i in range(repetitions):
            init_subsample = (1, 1)
            if i == 0 and not is_first_layer:
                init_subsample = (2, 2)
            input = block_function(nb_filter=nb_filter, init_subsample=init_subsample,
                                   is_first_block_of_first_layer=(is_first_layer and i == 0))(input)
        return input

    return f

# %%
def basic_block(nb_filter, init_subsample=(1, 1), is_first_block_of_first_layer=False):
    """Basic 3 X 3 convolution blocks for use on resnets with layers <= 34.
    Follows improved proposed scheme in http://arxiv.org/pdf/1603.05027v2.pdf
    """
    def f(input):

        if is_first_block_of_first_layer:
            # don't repeat bn->relu since we just did bn->relu->maxpool
            conv1 = Convolution2D(nb_filter=nb_filter,
                                 nb_row=3, nb_col=3,
                                 subsample=init_subsample,
                                 init="he_normal", border_mode="same",
                                 W_regularizer=l2(0.0001))(input)
        else:
            conv1 = _bn_relu_conv(nb_filter=nb_filter, nb_row=3, nb_col=3,
                                  subsample=init_subsample)(input)

        residual = _bn_relu_conv(nb_filter=nb_filter, nb_row=3, nb_col=3)(conv1)
        return _shortcut(input, residual)

    return f

# %%
def bottleneck(nb_filter, init_subsample=(1, 1), is_first_block_of_first_layer=False):
    """Bottleneck architecture for > 34 layer resnet.
    Follows improved proposed scheme in http://arxiv.org/pdf/1603.05027v2.pdf

    Returns:
        A final conv layer of nb_filter * 4
    """
    def f(input):

        if is_first_block_of_first_layer:
            # don't repeat bn->relu since we just did bn->relu->maxpool
            conv_1_1 = Convolution2D(nb_filter=nb_filter,
                                 nb_row=1, nb_col=1,
                                 subsample=init_subsample,
                                 init="he_normal", border_mode="same",
                                 W_regularizer=l2(0.0001))(input)
        else:
            conv_1_1 = _bn_relu_conv(nb_filter=nb_filter, nb_row=1, nb_col=1,
                                     subsample=init_subsample)(input)

        conv_3_3 = _bn_relu_conv(nb_filter=nb_filter, nb_row=3, nb_col=3)(conv_1_1)
        residual = _bn_relu_conv(nb_filter=nb_filter * 4, nb_row=1, nb_col=1)(conv_3_3)
        return _shortcut(input, residual)

    return f

# %%
def _handle_dim_ordering():
    global ROW_AXIS
    global COL_AXIS
    global CHANNEL_AXIS
    if K.image_dim_ordering() == 'tf':
        ROW_AXIS = 1
        COL_AXIS = 2
        CHANNEL_AXIS = 3
    else:
        CHANNEL_AXIS = 1
        ROW_AXIS = 2
        COL_AXIS = 3

# %%
def _get_block(identifier):
    if isinstance(identifier, six.string_types):
        res = globals().get(identifier)
        if not res:
            raise ValueError('Invalid {}'.format(identifier))
        return res
    return identifier

# %%
class ResnetBuilder(object):
    @staticmethod
    def build(input_shape, num_outputs, block_fn, repetitions):
        """Builds a custom ResNet like architecture.

        Args:
            input_shape: The input shape in the form (nb_channels, nb_rows, nb_cols)
            num_outputs: The number of outputs at final softmax layer
            block_fn: The block function to use. This is either `basic_block` or `bottleneck`.
                The original paper used basic_block for layers < 50
            repetitions: Number of repetitions of various block units.
                At each block unit, the number of filters are doubled and the input size is halved

        Returns:
            The keras `Model`.
        """
        _handle_dim_ordering()
        if len(input_shape) != 3:
            raise Exception("Input shape should be a tuple (nb_channels, nb_rows, nb_cols)")

        # Permute dimension order if necessary
        if K.image_dim_ordering() == 'tf':
            input_shape = (input_shape[1], input_shape[2], input_shape[0])

        # Load function from str if needed.
        block_fn = _get_block(block_fn)

        input = Input(shape=input_shape)
        conv1 = _conv_bn_relu(nb_filter=64, nb_row=7, nb_col=7, subsample=(2, 2))(input)
        pool1 = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), border_mode="same")(conv1)

        block = pool1
        nb_filter = 64
        for i, r in enumerate(repetitions):
            block = _residual_block(block_fn, nb_filter=nb_filter, repetitions=r, is_first_layer=(i == 0))(block)
            nb_filter *= 2

        # Last activation
        block = _bn_relu(block)

        block_norm = BatchNormalization(mode=0, axis=CHANNEL_AXIS)(block)
        block_output = Activation("relu")(block_norm)

        # Classifier block
        block_shape = K.int_shape(block)
        pool2 = AveragePooling2D(pool_size=(block_shape[ROW_AXIS], block_shape[COL_AXIS]),
                                 strides=(1, 1))(block_output)
        flatten1 = Flatten()(pool2)
        dense = Dense(output_dim=num_outputs, init="he_normal", activation="softmax")(flatten1)
        #dense = Dense(output_dim=num_outputs, W_regularizer=l2(0.01), init="he_normal", activation="linear")(flatten1)

        model = Model(input=input, output=dense)
        return model

    @staticmethod
    def build_resnet_test(input_shape, num_outputs):
        return ResnetBuilder.build(input_shape, num_outputs, basic_block, [1, 1, 1, 1])

    @staticmethod
    def build_resnet_18(input_shape, num_outputs):
        return ResnetBuilder.build(input_shape, num_outputs, basic_block, [2, 2, 2, 2])

    @staticmethod
    def build_resnet_34(input_shape, num_outputs):
        return ResnetBuilder.build(input_shape, num_outputs, basic_block, [3, 4, 6, 3])

    @staticmethod
    def build_resnet_50(input_shape, num_outputs):
        return ResnetBuilder.build(input_shape, num_outputs, bottleneck, [3, 4, 6, 3])

    @staticmethod
    def build_resnet_101(input_shape, num_outputs):
        return ResnetBuilder.build(input_shape, num_outputs, bottleneck, [3, 4, 23, 3])

    @staticmethod
    def build_resnet_152(input_shape, num_outputs):
        return ResnetBuilder.build(input_shape, num_outputs, bottleneck, [3, 8, 36, 3])

# %% [markdown]
# ## Batch Generator for model fit_generator

# %%
def batch_generator_train(files, batch_size):
    number_of_batches = np.ceil(len(files)/batch_size)
    counter = 0
    random.shuffle(files)
    while True:
        batch_files = files[batch_size*counter:batch_size*(counter+1)]
        image_list = []
        mask_list = []
        for f in batch_files:
            image = cv2.imread(f)
            image = cv2.resize(image, conf['image_shape'])

            cancer_type = f[20:21] # relies on path lengths that is hard coded below
            if cancer_type == '1':
                mask = [1, 0, 0]
            elif cancer_type == '2':
                mask = [0, 1, 0]
            else:
                mask = [0, 0, 1]

            image_list.append(image)
            mask_list.append(mask)
        counter += 1
        image_list = np.array(image_list)
        mask_list = np.array(mask_list)

        yield image_list, mask_list

        if counter == number_of_batches:
            random.shuffle(files)
            counter = 0

# %% [markdown]
# ## Hardcoded paths to training files. Note that "additional" has been renamed to "add01" since the path lengths must be the same for substring extraction.

# %%
# file paths to training and additional samples
filepaths = []
filepaths.append('./input/train/Type_1/')
filepaths.append('./input/train/Type_2/')
filepaths.append('./input/train/Type_3/')

# %% [markdown]
# ## Get a list of all training files

# %%
allFiles = []

for i, filepath in enumerate(filepaths):
    files = glob.glob(filepath + '*.jpg')
    allFiles = allFiles + files

# %% [markdown]
# ## Split data into training and validation sets

# %%
split_point = int(round(conf['train_valid_fraction']*len(allFiles)))

random.shuffle(allFiles)

train_list = allFiles[:split_point]
valid_list = allFiles[split_point:]
print('Train patients: {}'.format(len(train_list)))
print('Valid patients: {}'.format(len(valid_list)))
# Out:
# Train patients: 1111
# Valid patients: 370

# %% [markdown]
# ## Testing model generator

# %%
print('Create and compile model...')

nb_classes = 3
img_rows, img_cols = conf['image_shape'][1], conf['image_shape'][0]
img_channels = 3

model = ResnetBuilder.build_resnet_34((img_channels, img_rows, img_cols), nb_classes)
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
#model.compile(loss='hinge',optimizer='adadelta',metrics=['accuracy'])

callbacks = [
    EarlyStopping(monitor='val_loss', patience=conf['patience'], verbose=0),
    ModelCheckpoint('cervical_best.hdf5', monitor='val_loss', save_best_only=True, verbose=0),
]

print('Fit model...')
fit = model.fit_generator(generator=batch_generator_train(train_list, conf['batch_size']),
                      nb_epoch=conf['nb_epoch'],
                      samples_per_epoch=len(train_list),
                      validation_data=batch_generator_train(valid_list, conf['batch_size']),
                      nb_val_samples=len(valid_list),
                      verbose=1,
                      callbacks=callbacks)
# Out:
# Create and compile model...
# Fit model...
# Epoch 1/100
# 1111/1111 [==============================] - 520s - loss: 0.1747 - acc: 0.9811 - val_loss: 16.1181 - val_acc: 0.0000e+00
# Epoch 2/100
# 1111/1111 [==============================] - 418s - loss: 0.1030 - acc: 1.0000 - val_loss: 6.2757e-05 - val_acc: 1.0000
# Epoch 3/100
# 1111/1111 [==============================] - 376s - loss: 0.0999 - acc: 1.0000 - val_loss: 0.0300 - val_acc: 1.0000
# Epoch 4/100
# 1111/1111 [==============================] - 361s - loss: 0.0980 - acc: 1.0000 - val_loss: 0.1009 - val_acc: 1.0000
# Epoch 5/100
# 1111/1111 [==============================] - 398s - loss: 0.0966 - acc: 1.0000 - val_loss: 0.0846 - val_acc: 1.0000
# Epoch 6/100
# 1111/1111 [==============================] - 352s - loss: 0.0954 - acc: 1.0000 - val_loss: 0.0601 - val_acc: 1.0000

# %% [markdown]
# ## Create submission files with prediction for submission

# %%
from keras.models import load_model
model = load_model('cervical_best.hdf5')

sample_subm = pd.read_csv("./input/sample_submission.csv")
ids = sample_subm['image_name'].values

for id in ids:
    print('Predict for image {}'.format(id))
    files = glob.glob("./input/test/" + id)
    image_list = []
    for f in files:
        image = cv2.imread(f)
        image = cv2.resize(image, conf['image_shape'])
        image_list.append(image)
        
    image_list = np.array(image_list)

    predictions = model.predict(image_list, verbose=1, batch_size=1)

    sample_subm.loc[sample_subm['image_name'] == id, 'Type_1'] = predictions[0,0]
    sample_subm.loc[sample_subm['image_name'] == id, 'Type_2'] = predictions[0,1]
    sample_subm.loc[sample_subm['image_name'] == id, 'Type_3'] = predictions[0,2]
    
sample_subm.to_csv("subm.csv", index=False)
# Out:
# Predict for image 0.jpg
# 1/1 [==============================] - 1s
# Predict for image 1.jpg
# 1/1 [==============================] - 0s
# Predict for image 2.jpg
# 1/1 [==============================] - 0s
# Predict for image 3.jpg
# 1/1 [==============================] - 0s
# Predict for image 4.jpg
# 1/1 [==============================] - 0s
# Predict for image 5.jpg
# 1/1 [==============================] - 0s
# Predict for image 6.jpg
# 1/1 [==============================] - 0s
# Predict for image 7.jpg
# 1/1 [==============================] - 0s
# Predict for image 8.jpg
# 1/1 [==============================] - 0s
# Predict for image 9.jpg
# 1/1 [==============================] - 0s
# Predict for image 10.jpg
# 1/1 [==============================] - 0s
# Predict for image 11.jpg
# 1/1 [==============================] - 0s
# Predict for image 12.jpg
# 1/1 [==============================] - 0s
# Predict for image 13.jpg
# 1/1 [==============================] - 0s
# Predict for image 14.jpg
# 1/1 [==============================] - 0s
# Predict for image 15.jpg
# 1/1 [==============================] - 0s
# Predict for image 16.jpg
# 1/1 [==============================] - 0s
# Predict for image 17.jpg
# 1/1 [==============================] - 0s
# Predict for image 18.jpg
# 1/1 [==============================] - 0s
# Predict for image 19.jpg
# 1/1 [==============================] - 0s
# Predict for image 20.jpg
# 1/1 [==============================] - 0s
# Predict for image 21.jpg
# 1/1 [==============================] - 0s
# Predict for image 22.jpg
# 1/1 [==============================] - 0s
# Predict for image 23.jpg
# 1/1 [==============================] - 0s
# Predict for image 24.jpg
# 1/1 [==============================] - 0s
# Predict for image 25.jpg
# 1/1 [==============================] - 0s
# Predict for image 26.jpg
# 1/1 [==============================] - 0s
# Predict for image 27.jpg
# 1/1 [==============================] - 0s
# Predict for image 28.jpg
# 1/1 [==============================] - 0s
# Predict for image 29.jpg
# 1/1 [==============================] - 0s
# Predict for image 30.jpg
# 1/1 [==============================] - 0s
# Predict for image 31.jpg
# 1/1 [==============================] - 0s
# Predict for image 32.jpg
# 1/1 [==============================] - 0s
# Predict for image 33.jpg
# 1/1 [==============================] - 0s
# Predict for image 34.jpg
# 1/1 [==============================] - 0s
# Predict for image 35.jpg
# 1/1 [==============================] - 0s
# Predict for image 36.jpg
# 1/1 [==============================] - 0s
# Predict for image 37.jpg
# 1/1 [==============================] - 0s
# Predict for image 38.jpg
# 1/1 [==============================] - 0s
# Predict for image 39.jpg
# 1/1 [==============================] - 0s
# Predict for image 40.jpg
# 1/1 [==============================] - 0s
# Predict for image 41.jpg
# 1/1 [==============================] - 0s
# Predict for image 42.jpg
# 1/1 [==============================] - 0s
# Predict for image 43.jpg
# 1/1 [==============================] - 0s
# Predict for image 44.jpg
# 1/1 [==============================] - 0s
# Predict for image 45.jpg
# 1/1 [==============================] - 0s
# Predict for image 46.jpg
# 1/1 [==============================] - 0s
# Predict for image 47.jpg
# 1/1 [==============================] - 0s
# Predict for image 48.jpg
# 1/1 [==============================] - 0s
# Predict for image 49.jpg
# 1/1 [==============================] - 0s
# Predict for image 50.jpg
# 1/1 [==============================] - 0s
# Predict for image 51.jpg
# 1/1 [==============================] - 0s
# Predict for image 52.jpg
# 1/1 [==============================] - 0s
# Predict for image 53.jpg
# 1/1 [==============================] - 0s
# Predict for image 54.jpg
# 1/1 [==============================] - 0s
# Predict for image 55.jpg
# 1/1 [==============================] - 0s
# Predict for image 56.jpg
# 1/1 [==============================] - 0s
# Predict for image 57.jpg
# 1/1 [==============================] - 0s
# Predict for image 58.jpg
# 1/1 [==============================] - 0s
# Predict for image 59.jpg
# 1/1 [==============================] - 0s
# Predict for image 60.jpg
# 1/1 [==============================] - 0s
# Predict for image 61.jpg
# 1/1 [==============================] - 0s
# Predict for image 62.jpg
# 1/1 [==============================] - 0s
# Predict for image 63.jpg
# 1/1 [==============================] - 0s
# Predict for image 64.jpg
# 1/1 [==============================] - 0s
# Predict for image 65.jpg
# 1/1 [==============================] - 0s
# Predict for image 66.jpg
# 1/1 [==============================] - 0s
# Predict for image 67.jpg
# 1/1 [==============================] - 0s
# Predict for image 68.jpg
# 1/1 [==============================] - 0s
# Predict for image 69.jpg
# 1/1 [==============================] - 0s
# Predict for image 70.jpg
# 1/1 [==============================] - 0s
# Predict for image 71.jpg
# 1/1 [==============================] - 0s
# Predict for image 72.jpg
# 1/1 [==============================] - 0s
# Predict for image 73.jpg
# 1/1 [==============================] - 0s
# Predict for image 74.jpg
# 1/1 [==============================] - 0s
# Predict for image 75.jpg
# 1/1 [==============================] - 0s
# Predict for image 76.jpg
# 1/1 [==============================] - 0s
# Predict for image 77.jpg
# 1/1 [==============================] - 0s
# Predict for image 78.jpg
# 1/1 [==============================] - 0s
# Predict for image 79.jpg
# 1/1 [==============================] - 0s
# Predict for image 80.jpg
# 1/1 [==============================] - 0s
# Predict for image 81.jpg
# 1/1 [==============================] - 0s
# Predict for image 82.jpg
# 1/1 [==============================] - 0s
# Predict for image 83.jpg
# 1/1 [==============================] - 0s
# Predict for image 84.jpg
# 1/1 [==============================] - 0s
# Predict for image 85.jpg
# 1/1 [==============================] - 0s
# Predict for image 86.jpg
# 1/1 [==============================] - 0s
# Predict for image 87.jpg
# 1/1 [==============================] - 0s
# Predict for image 88.jpg
# 1/1 [==============================] - 0s
# Predict for image 89.jpg
# 1/1 [==============================] - 0s
# Predict for image 90.jpg
# 1/1 [==============================] - 0s
# Predict for image 91.jpg
# 1/1 [==============================] - 0s
# Predict for image 92.jpg
# 1/1 [==============================] - 0s
# Predict for image 93.jpg
# 1/1 [==============================] - 0s
# Predict for image 94.jpg
# 1/1 [==============================] - 0s
# Predict for image 95.jpg
# 1/1 [==============================] - 0s
# Predict for image 96.jpg
# 1/1 [==============================] - 0s
# Predict for image 97.jpg
# 1/1 [==============================] - 0s
# Predict for image 98.jpg
# 1/1 [==============================] - 0s
# Predict for image 99.jpg
# 1/1 [==============================] - 0s
# Predict for image 100.jpg
# 1/1 [==============================] - 0s
# Predict for image 101.jpg
# 1/1 [==============================] - 0s
# Predict for image 102.jpg
# 1/1 [==============================] - 0s
# Predict for image 103.jpg
# 1/1 [==============================] - 0s
# Predict for image 104.jpg
# 1/1 [==============================] - 0s
# Predict for image 105.jpg
# 1/1 [==============================] - 0s
# Predict for image 106.jpg
# 1/1 [==============================] - 0s
# Predict for image 107.jpg
# 1/1 [==============================] - 0s
# Predict for image 108.jpg
# 1/1 [==============================] - 0s
# Predict for image 109.jpg
# 1/1 [==============================] - 0s
# Predict for image 110.jpg
# 1/1 [==============================] - 0s
# Predict for image 111.jpg
# 1/1 [==============================] - 0s
# Predict for image 112.jpg
# 1/1 [==============================] - 0s
# Predict for image 113.jpg
# 1/1 [==============================] - 0s
# Predict for image 114.jpg
# 1/1 [==============================] - 0s
# Predict for image 115.jpg
# 1/1 [==============================] - 0s
# Predict for image 116.jpg
# 1/1 [==============================] - 0s
# Predict for image 117.jpg
# 1/1 [==============================] - 0s
# Predict for image 118.jpg
# 1/1 [==============================] - 0s
# Predict for image 119.jpg
# 1/1 [==============================] - 0s
# Predict for image 120.jpg
# 1/1 [==============================] - 0s
# Predict for image 121.jpg
# 1/1 [==============================] - 0s
# Predict for image 122.jpg
# 1/1 [==============================] - 0s
# Predict for image 123.jpg
# 1/1 [==============================] - 0s
# Predict for image 124.jpg
# 1/1 [==============================] - 0s
# Predict for image 125.jpg
# 1/1 [==============================] - 0s
# Predict for image 126.jpg
# 1/1 [==============================] - 0s
# Predict for image 127.jpg
# 1/1 [==============================] - 0s
# Predict for image 128.jpg
# 1/1 [==============================] - 0s
# Predict for image 129.jpg
# 1/1 [==============================] - 0s
# Predict for image 130.jpg
# 1/1 [==============================] - 0s
# Predict for image 131.jpg
# 1/1 [==============================] - 0s
# Predict for image 132.jpg
# 1/1 [==============================] - 0s
# Predict for image 133.jpg
# 1/1 [==============================] - 0s
# Predict for image 134.jpg
# 1/1 [==============================] - 0s
# Predict for image 135.jpg
# 1/1 [==============================] - 0s
# Predict for image 136.jpg
# 1/1 [==============================] - 0s
# Predict for image 137.jpg
# 1/1 [==============================] - 0s
# Predict for image 138.jpg
# 1/1 [==============================] - 0s
# Predict for image 139.jpg
# 1/1 [==============================] - 0s
# Predict for image 140.jpg
# 1/1 [==============================] - 0s
# Predict for image 141.jpg
# 1/1 [==============================] - 0s
# Predict for image 142.jpg
# 1/1 [==============================] - 0s
# Predict for image 143.jpg
# 1/1 [==============================] - 0s
# Predict for image 144.jpg
# 1/1 [==============================] - 0s
# Predict for image 145.jpg
# 1/1 [==============================] - 0s
# Predict for image 146.jpg
# 1/1 [==============================] - 0s
# Predict for image 147.jpg
# 1/1 [==============================] - 0s
# Predict for image 148.jpg
# 1/1 [==============================] - 0s
# Predict for image 149.jpg
# 1/1 [==============================] - 0s
# Predict for image 150.jpg
# 1/1 [==============================] - 0s
# Predict for image 151.jpg
# 1/1 [==============================] - 0s
# Predict for image 152.jpg
# 1/1 [==============================] - 0s
# Predict for image 153.jpg
# 1/1 [==============================] - 0s
# Predict for image 154.jpg
# 1/1 [==============================] - 0s
# Predict for image 155.jpg
# 1/1 [==============================] - 0s
# Predict for image 156.jpg
# 1/1 [==============================] - 0s
# Predict for image 157.jpg
# 1/1 [==============================] - 0s
# Predict for image 158.jpg
# 1/1 [==============================] - 0s
# Predict for image 159.jpg
# 1/1 [==============================] - 0s
# Predict for image 160.jpg
# 1/1 [==============================] - 0s
# Predict for image 161.jpg
# 1/1 [==============================] - 0s
# Predict for image 162.jpg
# 1/1 [==============================] - 0s
# Predict for image 163.jpg
# 1/1 [==============================] - 0s
# Predict for image 164.jpg
# 1/1 [==============================] - 0s
# Predict for image 165.jpg
# 1/1 [==============================] - 0s
# Predict for image 166.jpg
# 1/1 [==============================] - 0s
# Predict for image 167.jpg
# 1/1 [==============================] - 0s
# Predict for image 168.jpg
# 1/1 [==============================] - 0s
# Predict for image 169.jpg
# 1/1 [==============================] - 0s
# Predict for image 170.jpg
# 1/1 [==============================] - 0s
# Predict for image 171.jpg
# 1/1 [==============================] - 0s
# Predict for image 172.jpg
# 1/1 [==============================] - 0s
# Predict for image 173.jpg
# 1/1 [==============================] - 0s
# Predict for image 174.jpg
# 1/1 [==============================] - 0s
# Predict for image 175.jpg
# 1/1 [==============================] - 0s
# Predict for image 176.jpg
# 1/1 [==============================] - 0s
# Predict for image 177.jpg
# 1/1 [==============================] - 0s
# Predict for image 178.jpg
# 1/1 [==============================] - 0s
# Predict for image 179.jpg
# 1/1 [==============================] - 0s
# Predict for image 180.jpg
# 1/1 [==============================] - 0s
# Predict for image 181.jpg
# 1/1 [==============================] - 0s
# Predict for image 182.jpg
# 1/1 [==============================] - 0s
# Predict for image 183.jpg
# 1/1 [==============================] - 0s
# Predict for image 184.jpg
# 1/1 [==============================] - 0s
# Predict for image 185.jpg
# 1/1 [==============================] - 0s
# Predict for image 186.jpg
# 1/1 [==============================] - 0s
# Predict for image 187.jpg
# 1/1 [==============================] - 0s
# Predict for image 188.jpg
# 1/1 [==============================] - 0s
# Predict for image 189.jpg
# 1/1 [==============================] - 0s
# Predict for image 190.jpg
# 1/1 [==============================] - 0s
# Predict for image 191.jpg
# 1/1 [==============================] - 0s
# Predict for image 192.jpg
# 1/1 [==============================] - 0s
# Predict for image 193.jpg
# 1/1 [==============================] - 0s
# Predict for image 194.jpg
# 1/1 [==============================] - 0s
# Predict for image 195.jpg
# 1/1 [==============================] - 0s
# Predict for image 196.jpg
# 1/1 [==============================] - 0s
# Predict for image 197.jpg
# 1/1 [==============================] - 0s
# Predict for image 198.jpg
# 1/1 [==============================] - 0s
# Predict for image 199.jpg
# 1/1 [==============================] - 0s
# Predict for image 200.jpg
# 1/1 [==============================] - 0s
# Predict for image 201.jpg
# 1/1 [==============================] - 0s
# Predict for image 202.jpg
# 1/1 [==============================] - 0s
# Predict for image 203.jpg
# 1/1 [==============================] - 0s
# Predict for image 204.jpg
# 1/1 [==============================] - 0s
# Predict for image 205.jpg
# 1/1 [==============================] - 0s
# Predict for image 206.jpg
# 1/1 [==============================] - 0s
# Predict for image 207.jpg
# 1/1 [==============================] - 0s
# Predict for image 208.jpg
# 1/1 [==============================] - 0s
# Predict for image 209.jpg
# 1/1 [==============================] - 0s
# Predict for image 210.jpg
# 1/1 [==============================] - 0s
# Predict for image 211.jpg
# 1/1 [==============================] - 0s
# Predict for image 212.jpg
# 1/1 [==============================] - 0s
# Predict for image 213.jpg
# 1/1 [==============================] - 0s
# Predict for image 214.jpg
# 1/1 [==============================] - 0s
# Predict for image 215.jpg
# 1/1 [==============================] - 0s
# Predict for image 216.jpg
# 1/1 [==============================] - 0s
# Predict for image 217.jpg
# 1/1 [==============================] - 0s
# Predict for image 218.jpg
# 1/1 [==============================] - 0s
# Predict for image 219.jpg
# 1/1 [==============================] - 0s
# Predict for image 220.jpg
# 1/1 [==============================] - 0s
# Predict for image 221.jpg
# 1/1 [==============================] - 0s
# Predict for image 222.jpg
# 1/1 [==============================] - 0s
# Predict for image 223.jpg
# 1/1 [==============================] - 0s
# Predict for image 224.jpg
# 1/1 [==============================] - 0s
# Predict for image 225.jpg
# 1/1 [==============================] - 0s
# Predict for image 226.jpg
# 1/1 [==============================] - 0s
# Predict for image 227.jpg
# 1/1 [==============================] - 0s
# Predict for image 228.jpg
# 1/1 [==============================] - 0s
# Predict for image 229.jpg
# 1/1 [==============================] - 0s
# Predict for image 230.jpg
# 1/1 [==============================] - 0s
# Predict for image 231.jpg
# 1/1 [==============================] - 0s
# Predict for image 232.jpg
# 1/1 [==============================] - 0s
# Predict for image 233.jpg
# 1/1 [==============================] - 0s
# Predict for image 234.jpg
# 1/1 [==============================] - 0s
# Predict for image 235.jpg
# 1/1 [==============================] - 0s
# Predict for image 236.jpg
# 1/1 [==============================] - 0s
# Predict for image 237.jpg
# 1/1 [==============================] - 0s
# Predict for image 238.jpg
# 1/1 [==============================] - 0s
# Predict for image 239.jpg
# 1/1 [==============================] - 0s
# Predict for image 240.jpg
# 1/1 [==============================] - 0s
# Predict for image 241.jpg
# 1/1 [==============================] - 0s
# Predict for image 242.jpg
# 1/1 [==============================] - 0s
# Predict for image 243.jpg
# 1/1 [==============================] - 0s
# Predict for image 244.jpg
# 1/1 [==============================] - 0s
# Predict for image 245.jpg
# 1/1 [==============================] - 0s
# Predict for image 246.jpg
# 1/1 [==============================] - 0s
# Predict for image 247.jpg
# 1/1 [==============================] - 0s
# Predict for image 248.jpg
# 1/1 [==============================] - 0s
# Predict for image 249.jpg
# 1/1 [==============================] - 0s
# Predict for image 250.jpg
# 1/1 [==============================] - 0s
# Predict for image 251.jpg
# 1/1 [==============================] - 0s
# Predict for image 252.jpg
# 1/1 [==============================] - 0s
# Predict for image 253.jpg
# 1/1 [==============================] - 0s
# Predict for image 254.jpg
# 1/1 [==============================] - 0s
# Predict for image 255.jpg
# 1/1 [==============================] - 0s
# Predict for image 256.jpg
# 1/1 [==============================] - 0s
# Predict for image 257.jpg
# 1/1 [==============================] - 0s
# Predict for image 258.jpg
# 1/1 [==============================] - 0s
# Predict for image 259.jpg
# 1/1 [==============================] - 0s
# Predict for image 260.jpg
# 1/1 [==============================] - 0s
# Predict for image 261.jpg
# 1/1 [==============================] - 0s
# Predict for image 262.jpg
# 1/1 [==============================] - 0s
# Predict for image 263.jpg
# 1/1 [==============================] - 0s
# Predict for image 264.jpg
# 1/1 [==============================] - 0s
# Predict for image 265.jpg
# 1/1 [==============================] - 0s
# Predict for image 266.jpg
# 1/1 [==============================] - 0s
# Predict for image 267.jpg
# 1/1 [==============================] - 0s
# Predict for image 268.jpg
# 1/1 [==============================] - 0s
# Predict for image 269.jpg
# 1/1 [==============================] - 0s
# Predict for image 270.jpg
# 1/1 [==============================] - 0s
# Predict for image 271.jpg
# 1/1 [==============================] - 0s
# Predict for image 272.jpg
# 1/1 [==============================] - 0s
# Predict for image 273.jpg
# 1/1 [==============================] - 0s
# Predict for image 274.jpg
# 1/1 [==============================] - 0s
# Predict for image 275.jpg
# 1/1 [==============================] - 0s
# Predict for image 276.jpg
# 1/1 [==============================] - 0s
# Predict for image 277.jpg
# 1/1 [==============================] - 0s
# Predict for image 278.jpg
# 1/1 [==============================] - 0s
# Predict for image 279.jpg
# 1/1 [==============================] - 0s
# Predict for image 280.jpg
# 1/1 [==============================] - 0s
# Predict for image 281.jpg
# 1/1 [==============================] - 0s
# Predict for image 282.jpg
# 1/1 [==============================] - 0s
# Predict for image 283.jpg
# 1/1 [==============================] - 0s
# Predict for image 284.jpg
# 1/1 [==============================] - 0s
# Predict for image 285.jpg
# 1/1 [==============================] - 0s
# Predict for image 286.jpg
# 1/1 [==============================] - 0s
# Predict for image 287.jpg
# 1/1 [==============================] - 0s
# Predict for image 288.jpg
# 1/1 [==============================] - 0s
# Predict for image 289.jpg
# 1/1 [==============================] - 0s
# Predict for image 290.jpg
# 1/1 [==============================] - 0s
# Predict for image 291.jpg
# 1/1 [==============================] - 0s
# Predict for image 292.jpg
# 1/1 [==============================] - 0s
# Predict for image 293.jpg
# 1/1 [==============================] - 0s
# Predict for image 294.jpg
# 1/1 [==============================] - 0s
# Predict for image 295.jpg
# 1/1 [==============================] - 0s
# Predict for image 296.jpg
# 1/1 [==============================] - 0s
# Predict for image 297.jpg
# 1/1 [==============================] - 0s
# Predict for image 298.jpg
# 1/1 [==============================] - 0s
# Predict for image 299.jpg
# 1/1 [==============================] - 0s
# Predict for image 300.jpg
# 1/1 [==============================] - 0s
# Predict for image 301.jpg
# 1/1 [==============================] - 0s
# Predict for image 302.jpg
# 1/1 [==============================] - 0s
# Predict for image 303.jpg
# 1/1 [==============================] - 0s
# Predict for image 304.jpg
# 1/1 [==============================] - 0s
# Predict for image 305.jpg
# 1/1 [==============================] - 0s
# Predict for image 306.jpg
# 1/1 [==============================] - 0s
# Predict for image 307.jpg
# 1/1 [==============================] - 0s
# Predict for image 308.jpg
# 1/1 [==============================] - 0s
# Predict for image 309.jpg
# 1/1 [==============================] - 0s
# Predict for image 310.jpg
# 1/1 [==============================] - 0s
# Predict for image 311.jpg
# 1/1 [==============================] - 0s
# Predict for image 312.jpg
# 1/1 [==============================] - 0s
# Predict for image 313.jpg
# 1/1 [==============================] - 0s
# Predict for image 314.jpg
# 1/1 [==============================] - 0s
# Predict for image 315.jpg
# 1/1 [==============================] - 0s
# Predict for image 316.jpg
# 1/1 [==============================] - 0s
# Predict for image 317.jpg
# 1/1 [==============================] - 0s
# Predict for image 318.jpg
# 1/1 [==============================] - 0s
# Predict for image 319.jpg
# 1/1 [==============================] - 0s
# Predict for image 320.jpg
# 1/1 [==============================] - 0s
# Predict for image 321.jpg
# 1/1 [==============================] - 0s
# Predict for image 322.jpg
# 1/1 [==============================] - 0s
# Predict for image 323.jpg
# 1/1 [==============================] - 0s
# Predict for image 324.jpg
# 1/1 [==============================] - 0s
# Predict for image 325.jpg
# 1/1 [==============================] - 0s
# Predict for image 326.jpg
# 1/1 [==============================] - 0s
# Predict for image 327.jpg
# 1/1 [==============================] - 0s
# Predict for image 328.jpg
# 1/1 [==============================] - 0s
# Predict for image 329.jpg
# 1/1 [==============================] - 0s
# Predict for image 330.jpg
# 1/1 [==============================] - 0s
# Predict for image 331.jpg
# 1/1 [==============================] - 0s
# Predict for image 332.jpg
# 1/1 [==============================] - 0s
# Predict for image 333.jpg
# 1/1 [==============================] - 0s
# Predict for image 334.jpg
# 1/1 [==============================] - 0s
# Predict for image 335.jpg
# 1/1 [==============================] - 0s
# Predict for image 336.jpg
# 1/1 [==============================] - 0s
# Predict for image 337.jpg
# 1/1 [==============================] - 0s
# Predict for image 338.jpg
# 1/1 [==============================] - 0s
# Predict for image 339.jpg
# 1/1 [==============================] - 0s
# Predict for image 340.jpg
# 1/1 [==============================] - 0s
# Predict for image 341.jpg
# 1/1 [==============================] - 0s
# Predict for image 342.jpg
# 1/1 [==============================] - 0s
# Predict for image 343.jpg
# 1/1 [==============================] - 0s
# Predict for image 344.jpg
# 1/1 [==============================] - 0s
# Predict for image 345.jpg
# 1/1 [==============================] - 0s
# Predict for image 346.jpg
# 1/1 [==============================] - 0s
# Predict for image 347.jpg
# 1/1 [==============================] - 0s
# Predict for image 348.jpg
# 1/1 [==============================] - 0s
# Predict for image 349.jpg
# 1/1 [==============================] - 0s
# Predict for image 350.jpg
# 1/1 [==============================] - 0s
# Predict for image 351.jpg
# 1/1 [==============================] - 0s
# Predict for image 352.jpg
# 1/1 [==============================] - 0s
# Predict for image 353.jpg
# 1/1 [==============================] - 0s
# Predict for image 354.jpg
# 1/1 [==============================] - 0s
# Predict for image 355.jpg
# 1/1 [==============================] - 0s
# Predict for image 356.jpg
# 1/1 [==============================] - 0s
# Predict for image 357.jpg
# 1/1 [==============================] - 0s
# Predict for image 358.jpg
# 1/1 [==============================] - 0s
# Predict for image 359.jpg
# 1/1 [==============================] - 0s
# Predict for image 360.jpg
# 1/1 [==============================] - 0s
# Predict for image 361.jpg
# 1/1 [==============================] - 0s
# Predict for image 362.jpg
# 1/1 [==============================] - 0s
# Predict for image 363.jpg
# 1/1 [==============================] - 0s
# Predict for image 364.jpg
# 1/1 [==============================] - 0s
# Predict for image 365.jpg
# 1/1 [==============================] - 0s
# Predict for image 366.jpg
# 1/1 [==============================] - 0s
# Predict for image 367.jpg
# 1/1 [==============================] - 0s
# Predict for image 368.jpg
# 1/1 [==============================] - 0s
# Predict for image 369.jpg
# 1/1 [==============================] - 0s
# Predict for image 370.jpg
# 1/1 [==============================] - 0s
# Predict for image 371.jpg
# 1/1 [==============================] - 0s
# Predict for image 372.jpg
# 1/1 [==============================] - 0s
# Predict for image 373.jpg
# 1/1 [==============================] - 0s
# Predict for image 374.jpg
# 1/1 [==============================] - 0s
# Predict for image 375.jpg
# 1/1 [==============================] - 0s
# Predict for image 376.jpg
# 1/1 [==============================] - 0s
# Predict for image 377.jpg
# 1/1 [==============================] - 0s
# Predict for image 378.jpg
# 1/1 [==============================] - 0s
# Predict for image 379.jpg
# 1/1 [==============================] - 0s
# Predict for image 380.jpg
# 1/1 [==============================] - 0s
# Predict for image 381.jpg
# 1/1 [==============================] - 0s
# Predict for image 382.jpg
# 1/1 [==============================] - 0s
# Predict for image 383.jpg
# 1/1 [==============================] - 0s
# Predict for image 384.jpg
# 1/1 [==============================] - 0s
# Predict for image 385.jpg
# 1/1 [==============================] - 0s
# Predict for image 386.jpg
# 1/1 [==============================] - 0s
# Predict for image 387.jpg
# 1/1 [==============================] - 0s
# Predict for image 388.jpg
# 1/1 [==============================] - 0s
# Predict for image 389.jpg
# 1/1 [==============================] - 0s
# Predict for image 390.jpg
# 1/1 [==============================] - 0s
# Predict for image 391.jpg
# 1/1 [==============================] - 0s
# Predict for image 392.jpg
# 1/1 [==============================] - 0s
# Predict for image 393.jpg
# 1/1 [==============================] - 0s
# Predict for image 394.jpg
# 1/1 [==============================] - 0s
# Predict for image 395.jpg
# 1/1 [==============================] - 0s
# Predict for image 396.jpg
# 1/1 [==============================] - 0s
# Predict for image 397.jpg
# 1/1 [==============================] - 0s
# Predict for image 398.jpg
# 1/1 [==============================] - 0s
# Predict for image 399.jpg
# 1/1 [==============================] - 0s
# Predict for image 400.jpg
# 1/1 [==============================] - 0s
# Predict for image 401.jpg
# 1/1 [==============================] - 0s
# Predict for image 402.jpg
# 1/1 [==============================] - 0s
# Predict for image 403.jpg
# 1/1 [==============================] - 0s
# Predict for image 404.jpg
# 1/1 [==============================] - 0s
# Predict for image 405.jpg
# 1/1 [==============================] - 0s
# Predict for image 406.jpg
# 1/1 [==============================] - 0s
# Predict for image 407.jpg
# 1/1 [==============================] - 0s
# Predict for image 408.jpg
# 1/1 [==============================] - 0s
# Predict for image 409.jpg
# 1/1 [==============================] - 0s
# Predict for image 410.jpg
# 1/1 [==============================] - 0s
# Predict for image 411.jpg
# 1/1 [==============================] - 0s
# Predict for image 412.jpg
# 1/1 [==============================] - 0s
# Predict for image 413.jpg
# 1/1 [==============================] - 0s
# Predict for image 414.jpg
# 1/1 [==============================] - 0s
# Predict for image 415.jpg
# 1/1 [==============================] - 0s
# Predict for image 416.jpg
# 1/1 [==============================] - 0s
# Predict for image 417.jpg
# 1/1 [==============================] - 0s
# Predict for image 418.jpg
# 1/1 [==============================] - 0s
# Predict for image 419.jpg
# 1/1 [==============================] - 0s
# Predict for image 420.jpg
# 1/1 [==============================] - 0s
# Predict for image 421.jpg
# 1/1 [==============================] - 0s
# Predict for image 422.jpg
# 1/1 [==============================] - 0s
# Predict for image 423.jpg
# 1/1 [==============================] - 0s
# Predict for image 424.jpg
# 1/1 [==============================] - 0s
# Predict for image 425.jpg
# 1/1 [==============================] - 0s
# Predict for image 426.jpg
# 1/1 [==============================] - 0s
# Predict for image 427.jpg
# 1/1 [==============================] - 0s
# Predict for image 428.jpg
# 1/1 [==============================] - 0s
# Predict for image 429.jpg
# 1/1 [==============================] - 0s
# Predict for image 430.jpg
# 1/1 [==============================] - 0s
# Predict for image 431.jpg
# 1/1 [==============================] - 0s
# Predict for image 432.jpg
# 1/1 [==============================] - 0s
# Predict for image 433.jpg
# 1/1 [==============================] - 0s
# Predict for image 434.jpg
# 1/1 [==============================] - 0s
# Predict for image 435.jpg
# 1/1 [==============================] - 0s
# Predict for image 436.jpg
# 1/1 [==============================] - 0s
# Predict for image 437.jpg
# 1/1 [==============================] - 0s
# Predict for image 438.jpg
# 1/1 [==============================] - 0s
# Predict for image 439.jpg
# 1/1 [==============================] - 0s
# Predict for image 440.jpg
# 1/1 [==============================] - 0s
# Predict for image 441.jpg
# 1/1 [==============================] - 0s
# Predict for image 442.jpg
# 1/1 [==============================] - 0s
# Predict for image 443.jpg
# 1/1 [==============================] - 0s
# Predict for image 444.jpg
# 1/1 [==============================] - 0s
# Predict for image 445.jpg
# 1/1 [==============================] - 0s
# Predict for image 446.jpg
# 1/1 [==============================] - 0s
# Predict for image 447.jpg
# 1/1 [==============================] - 0s
# Predict for image 448.jpg
# 1/1 [==============================] - 0s
# Predict for image 449.jpg
# 1/1 [==============================] - 0s
# Predict for image 450.jpg
# 1/1 [==============================] - 0s
# Predict for image 451.jpg
# 1/1 [==============================] - 0s
# Predict for image 452.jpg
# 1/1 [==============================] - 0s
# Predict for image 453.jpg
# 1/1 [==============================] - 0s
# Predict for image 454.jpg
# 1/1 [==============================] - 0s
# Predict for image 455.jpg
# 1/1 [==============================] - 0s
# Predict for image 456.jpg
# 1/1 [==============================] - 0s
# Predict for image 457.jpg
# 1/1 [==============================] - 0s
# Predict for image 458.jpg
# 1/1 [==============================] - 0s
# Predict for image 459.jpg
# 1/1 [==============================] - 0s
# Predict for image 460.jpg
# 1/1 [==============================] - 0s
# Predict for image 461.jpg
# 1/1 [==============================] - 0s
# Predict for image 462.jpg
# 1/1 [==============================] - 0s
# Predict for image 463.jpg
# 1/1 [==============================] - 0s
# Predict for image 464.jpg
# 1/1 [==============================] - 0s
# Predict for image 465.jpg
# 1/1 [==============================] - 0s
# Predict for image 466.jpg
# 1/1 [==============================] - 0s
# Predict for image 467.jpg
# 1/1 [==============================] - 0s
# Predict for image 468.jpg
# 1/1 [==============================] - 0s
# Predict for image 469.jpg
# 1/1 [==============================] - 0s
# Predict for image 470.jpg
# 1/1 [==============================] - 0s
# Predict for image 471.jpg
# 1/1 [==============================] - 0s
# Predict for image 472.jpg
# 1/1 [==============================] - 0s
# Predict for image 473.jpg
# 1/1 [==============================] - 0s
# Predict for image 474.jpg
# 1/1 [==============================] - 0s
# Predict for image 475.jpg
# 1/1 [==============================] - 0s
# Predict for image 476.jpg
# 1/1 [==============================] - 0s
# Predict for image 477.jpg
# 1/1 [==============================] - 0s
# Predict for image 478.jpg
# 1/1 [==============================] - 0s
# Predict for image 479.jpg
# 1/1 [==============================] - 0s
# Predict for image 480.jpg
# 1/1 [==============================] - 0s
# Predict for image 481.jpg
# 1/1 [==============================] - 0s
# Predict for image 482.jpg
# 1/1 [==============================] - 0s
# Predict for image 483.jpg
# 1/1 [==============================] - 0s
# Predict for image 484.jpg
# 1/1 [==============================] - 0s
# Predict for image 485.jpg
# 1/1 [==============================] - 0s
# Predict for image 486.jpg
# 1/1 [==============================] - 0s
# Predict for image 487.jpg
# 1/1 [==============================] - 0s
# Predict for image 488.jpg
# 1/1 [==============================] - 0s
# Predict for image 489.jpg
# 1/1 [==============================] - 0s
# Predict for image 490.jpg
# 1/1 [==============================] - 0s
# Predict for image 491.jpg
# 1/1 [==============================] - 0s
# Predict for image 492.jpg
# 1/1 [==============================] - 0s
# Predict for image 493.jpg
# 1/1 [==============================] - 0s
# Predict for image 494.jpg
# 1/1 [==============================] - 0s
# Predict for image 495.jpg
# 1/1 [==============================] - 0s
# Predict for image 496.jpg
# 1/1 [==============================] - 0s
# Predict for image 497.jpg
# 1/1 [==============================] - 0s
# Predict for image 498.jpg
# 1/1 [==============================] - 0s
# Predict for image 499.jpg
# 1/1 [==============================] - 0s
# Predict for image 500.jpg
# 1/1 [==============================] - 0s
# Predict for image 501.jpg
# 1/1 [==============================] - 0s
# Predict for image 502.jpg
# 1/1 [==============================] - 0s
# Predict for image 503.jpg
# 1/1 [==============================] - 0s
# Predict for image 504.jpg
# 1/1 [==============================] - 0s
# Predict for image 505.jpg
# 1/1 [==============================] - 0s
# Predict for image 506.jpg
# 1/1 [==============================] - 0s
# Predict for image 507.jpg
# 1/1 [==============================] - 0s
# Predict for image 508.jpg
# 1/1 [==============================] - 0s
# Predict for image 509.jpg
# 1/1 [==============================] - 0s
# Predict for image 510.jpg
# 1/1 [==============================] - 0s
# Predict for image 511.jpg
# 1/1 [==============================] - 0s
